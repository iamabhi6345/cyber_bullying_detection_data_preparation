# %%
cd ../
# Out:
# /app
# /home/abhi/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
train_df = pd.read_csv("./data/raw/ghc/ghc_train.tsv", sep="\t", header=0)
test_df = pd.read_csv("./data/raw/ghc/ghc_test.tsv", sep="\t", header=0)

# %%
print(f"{train_df.shape=}")
print(f"{test_df.shape=}")
# Out:
# train_df.shape=(22036, 4)
# test_df.shape=(5510, 4)

# %%
train_df.head(50)
# Out:
#                                                  text  hd  cv  vo
# 0   He most likely converted to islam due to his n...   0   0   0
# 1   So Ford lied about being a psychologist. Recor...   0   0   0
# 2      Jobs. Education. Ending abuse of Nation. CA43.   0   0   0
# 3   I share a lot of your values, & like many who ...   0   0   0
# 4   I am so ready to get back to blogging! www.ben...   0   0   0
# 5   taking a look at new opportunity called FX Pro...   0   0   0
# 6   Reflecting back when I was in school with Spec...   0   0   0
# 7   Let's be honest everyone, last year there were...   0   0   0
# 8                           2007 Nuke plant in Syria    0   0   0
# 9   NBC's Chuck Todd Thinks He's Figured It All Ou...   0   0   0
# 10                                     Nice one, lol    0   0   0
# 11  they must fail this midterm. Our republic depe...   0   0   0
# 12  'A confidential, 49-page memo for defeating Tr...   0   0   0
# 13  I was walking down the street with my husband ...   0   0   0
# 14  Suggestion: Create another channel not associa...   0   0   0
# 15                                           #camping   0   0   0
# 16                      Constitutional Conservatives    0   0   0
# 17  FB won't let me post the article that goes wit...   0   0   0
# 18                            Which Way Western Man..   0   0   0
# 19           Thanks, go Trump go ride the Trump train   0   0   0
# 20  to have flattering articles written about him ...   0   0   0
# 21  Democrats are tribal until a real socialist is...   0   0   0
# 22  Click on the live link for the latest and grea...   0   0   0
# 23  Go to qanon.pub for #QAnon posts coming fast a...   0   0   0
# 24  We are ALL tired of waiting . . realize someth...   0   0   0
# 25                                >>jews are at bay     0   0   0
# 26  https://thegoldwater.com/news/29277-Canada-Tru...   0   0   0
# 27  leave that shithole. let them kill each other....   0   0   0
# 28  do i have to take issue with it? i was enjoyin...   0   0   0
# 29  Saudi Money rules the Uk while Zionist Money r...   1   0   0
# 30  Max Reger -- 13 Chorale Preludes, Op. 79b http...   0   0   0
# 31  DAMN I LOVE OLD SCHOOL HIP HOP!!!!!!! I rememb...   0   0   0
# 32        Good morning, Jim. Happy Friday my friend 💜   0   0   0
# 33  Be a non-Muslim and Tweet respectfully about t...   0   0   0
# 34  EVERYONE needs to get off this color of skin k...   0   0   0
# 35  #Italy: Candidate says that all immigrants can...   1   0   0
# 36  Hold on. That law makes muslims sad and you ca...   0   0   0
# 37                                 Posted by u/AspenU   0   0   0
# 38  If you thought a Code of Conduct for your open...   0   0   0
# 39  A NOBLE LIE - OKLAHOMA CITY BOMBING 1995 DOCUM...   0   0   0
# 40  tfw you truly realize that America is just a m...   0   0   0
# 41  Have you ever wondered just how painfully diff...   0   0   0
# 42  Probing questions http://www.talesofmaora.com/...   0   0   0
# 43  may you be embraced by the angels and may your...   0   0   0
# 44  itsll get worse with the optic  of him sweatin...   0   0   0
# 45  Does ANYONE care what these immoral, sick, Hol...   1   0   1
# 46  “We need money and food,” said a 29-year-old m...   0   0   0
# 47  Imagine how many famous people may not have ex...   0   0   0
# 48                                 Give him a medal !   0   0   0
# 49  I hope she gets sodomised by a gang of Somali ...   1   1   1

# %%
test_df.head(10)
# Out:
#                                                 text  hd  cv  vo
# 0  https://www.youtube.com/watch?v=kACWpKAKtak A ...   0   0   0
# 1  Very nice! I tend to get tired of the constant...   0   0   0
# 2        Watch today. https://circumcisionmovie.com/   0   0   0
# 3  " Thinking Venues " First Color Layer blocking...   0   0   0
# 4  What about death penalty for perpetrators  and...   0   0   0
# 5                   You have insecurities? Fuck you    0   0   0
# 6  Powerful Truths About Donald Trump the Media D...   0   0   0
# 7         Just saw an Oreo cookie commercial. Drool.   0   0   0
# 8   I bet a neural net with half a dozen nodes co...   0   0   0
# 9  Country by country, the 'Prague Spring' that w...   0   0   0

# %%
cd /app
# Out:
# /app
# /home/abhi/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/raw/twitter/cyberbullying_tweets.csv")

# %%
print(f"{df.shape=}")
# Out:
# df.shape=(47692, 2)

# %%
(len(df) - (len(df) * 0.2)) * 0.25
# Out:
# 9538.4

# %%
df.sample(n=50)
# Out:
#                                               tweet_text   cyberbullying_type
# 18     Best pick up line? Hi, you're cute... ?: I lov...    not_cyberbullying
# 16939  @AyshaRenna why don't you raise your voice whe...             religion
# 9993   RT @IWantMooro: I'm sorry. Call me sexist but ...               gender
# 31972  No bc he would be the type of person 2 bully m...                  age
# 5208   I added a video to a @YouTube playlist https:/...    not_cyberbullying
# 27050  The scope of the problem can discourage people...  other_cyberbullying
# 964                                 @shanley #killallmen    not_cyberbullying
# 17410  If anyone is forcing you to something and just...             religion
# 10110  A female friend always calls my dance style un...               gender
# 31429  Plz stop demonizing black women's sexuality k thx  other_cyberbullying
# 3361   RT @curdistani: A group protesting #OzgecanAsl...    not_cyberbullying
# 35419  Devious Kisses, the first steamy bully romance...                  age
# 92     COLÉGIOS ADVENTISTAS DE SÃO PAULO DISCUTEM O B...    not_cyberbullying
# 28573                                            http:/…  other_cyberbullying
# 39826  So black coffee used his entire hand and nerve...            ethnicity
# 34524  girls who bullied me in high school are emotio...                  age
# 33669  Intramurals, first year high school. I was pra...                  age
# 4196                       @SexyDraco bullied for what??    not_cyberbullying
# 19280  U should be more worried about #Islamic terror...             religion
# 34868  Most of them aren’t even here for BTS but to l...                  age
# 43286  He went to Harvard Law School though? Dumb? RT...            ethnicity
# 46946                          oh ur the first one there            ethnicity
# 28583  There's some good info in the Talk section on ...  other_cyberbullying
# 14302  dont feed me that bullshit about how a person ...               gender
# 5228   @mikeofcc Slashing Net Neutrality "won't chang...    not_cyberbullying
# 43315  Cuhz y’all weirdos gotta stop this nigger talk...            ethnicity
# 26926  @TheSoundDefense only the existence of a sexua...  other_cyberbullying
# 21781  Are ppl so high that they use #IslamophobiaInI...             religion
# 39289  cancel @tylerisbaby she’s a HIGH SCHOOL FUCKIN...                  age
# 47020  u gota love racism today in #america insted of...            ethnicity
# 45714  Bitch just called him a dumb nigger he said bi...            ethnicity
# 44573  bitch made niggers up my ass obsessed m****fuc...            ethnicity
# 38500  RULES TO TEACH YOUR KIDS: Never shake a hand s...                  age
# 31494  @codemastermm I'm epic at color coordination. ...  other_cyberbullying
# 39979  @Giordanno12 you agreed to a double or nothing...            ethnicity
# 28454  @SFtheWolf http://t.co/g7w5b4uSbW is the one I...  other_cyberbullying
# 20234  Are you people born stupid or did you have to ...             religion
# 12215  All right let's see who actually drops dub dbz...               gender
# 1551   @gwallace17 Stafford need to perform tonight t...    not_cyberbullying
# 36945  Kante looks like the guy you could bully into ...                  age
# 751       I can't handle another round of this crap #mkr    not_cyberbullying
# 24896                           You piss me off so much.  other_cyberbullying
# 2156   “@kait_mitchell: Having a tour around bowland ...    not_cyberbullying
# 41151  @SunSteveBrenner I don't understand why he'd p...            ethnicity
# 45411  Finally ,FIR has been lodged against Rhea chak...            ethnicity
# 25630                             @kencf0618 awesome! :D  other_cyberbullying
# 21201  WE NEED TO UNDERSTAND SHIA KILLING SUNNIIIN NA...             religion
# 43271               @NotHaiu fuck you dumb stinky nigger            ethnicity
# 30647  I hate the assholes who don't turn off there b...  other_cyberbullying
# 14615  Boys that call girls ‘bitches’ and ‘females’ a...               gender

# %%
df["cyberbullying_type"].unique()
# Out:
# array(['not_cyberbullying', 'gender', 'religion', 'other_cyberbullying',
#        'age', 'ethnicity'], dtype=object)
